# %%
import pandas as pd
import pycristoforo as pyc
import datetime

# %%
df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv", 
                usecols = ["location","iso_code","date","people_vaccinated"])

# %%
df = df[df["location"] != "World"]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.fillna(method="ffill",inplace=True)

# %%
df["date"] = df["date"].apply(lambda x: datetime.datetime.strptime(x,"%Y-%m-%d"))

# %%
min_date = df["date"].min()
max_date = df["date"].max()

# %%
country_list = list(dict.fromkeys(zip(df["location"],df["iso_code"])))

# %%
for i in country_list:
    
    date_temp = min_date
    country_df = df[df["location"]==i[0]]
    country_min = country_df["date"].min()
    country_max = country_df["date"].max()
    vaccine_max = int(country_df[df["date"]==country_max]["people_vaccinated"])
        
    while date_temp <= max_date:
        if date_temp < country_min:
            df.loc[len(df)] = [i[0],i[1],date_temp,0]
        elif date_temp > country_max:
            df.loc[len(df)] = [i[0],i[1],date_temp, vaccine_max]
        date_temp += datetime.timedelta(days=1)
# Out:
# <ipython-input-63-e0a3f60c4005>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   vaccine_max = int(country_df[df["date"]==country_max]["people_vaccinated"])
# 6073
# 6073
# 2390
# 2762
# 558831
# 11908
# 339470
# 65000
# 290103
# 2850940
# 25578
# 20944
# 442640
# 12304
# 12304
# 6202055
# 153793
# 13101
# 972407
# 12710
# 3152171
# 3152171
# 66157
# 57162
# 135756
# 37570
# 391028
# 362158
# 26400
# 20784
# 20784
# 20784
# 15794992
# 68629
# 19243684
# 4190
# 1515
# 319559
# 2712800
# 3759906
# 20443
# 540039
# 2584
# 13950
# 1852
# 521283
# 19075
# 11206188
# 1461920
# 10000
# 226291
# 13286
# 4649708
# 2587866
# 21896
# 26025
# 137000
# 40680
# 40680
# 40680
# 143092
# 25285
# 25285
# 25285
# 49061
# 3843
# 1562401
# 1562401
# 3160479
# 103142
# 103142
# 103142
# 100
# 100
# 491593
# 308145
# 48641
# 72882
# 72882
# 225296
# 1959165
# 497040
# 100000
# 872361
# 2200000
# 2200000
# 2200000
# 1515980
# 4087
# 878143
# 47188
# 250000
# 297496
# ...

# %%
df.tail()
# Out:
#       location iso_code       date  people_vaccinated
# 8071  Zimbabwe      ZWE 2021-02-13                0.0
# 8072  Zimbabwe      ZWE 2021-02-14                0.0
# 8073  Zimbabwe      ZWE 2021-02-15                0.0
# 8074  Zimbabwe      ZWE 2021-02-16                0.0
# 8075  Zimbabwe      ZWE 2021-02-17                0.0

# %%
df = df.sort_values(by=["location","date"]).reset_index(drop=True)
df.tail()
# Out:
#       location iso_code       date  people_vaccinated
# 8071  Zimbabwe      ZWE 2021-02-21                0.0
# 8072  Zimbabwe      ZWE 2021-02-22             1314.0
# 8073  Zimbabwe      ZWE 2021-02-23             4041.0
# 8074  Zimbabwe      ZWE 2021-02-24             7872.0
# 8075  Zimbabwe      ZWE 2021-02-25            11007.0

# %%
df[df["location"]=="Russia"]
# Out:
#      location iso_code       date  people_vaccinated
# 6276   Russia      RUS 2020-12-13                0.0
# 6277   Russia      RUS 2020-12-14                0.0
# 6278   Russia      RUS 2020-12-15            28500.0
# 6279   Russia      RUS 2020-12-16            28500.0
# 6280   Russia      RUS 2020-12-17            28500.0
# ...       ...      ...        ...                ...
# 6346   Russia      RUS 2021-02-21          2200000.0
# 6347   Russia      RUS 2021-02-22          2200000.0
# 6348   Russia      RUS 2021-02-23          2200000.0
# 6349   Russia      RUS 2021-02-24          2200000.0
# 6350   Russia      RUS 2021-02-25          2200000.0
#
# [75 rows x 4 columns]

# %%
import plotly.express as px

fig = px.scatter_geo(df, locations="iso_code", locationmode="ISO-3",
                     size="people_vaccinated", 
                     hover_name="location",
                     animation_frame="date")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-f03fa69a11c2> in <module>
#       1 import plotly.express as px
#       2
# ----> 3 fig = px.scatter_geo(df, locations="iso_code", locationmode="ISO-3",
#       4                      size="people_vaccinated",
#       5                      hover_name="location",
#
# ...
